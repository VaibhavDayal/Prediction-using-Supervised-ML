# %% [markdown]
# # The Sparks Foundation
#
# #  TASK #1 - Prediction-using-Supervised-ML
#
# Predict the percentage of an student based on the no. of study hours.
#
# AUTHOR - VAIBHAV DAYAL

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# # IMPORT THE DATA SET

# %%
data = pd.read_csv('http://bit.ly/w-data')
data.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %% [markdown]
# # PLOTTIING RELATION BETWEEN THE MARKS PERCENTAGE AND HOURS STUDIED .

# %%
sns.set_style('darkgrid')
sns.scatterplot(y= data['Scores'], x= data['Hours'])
plt.title('Marks Vs Study Hours',size=20)
plt.ylabel('Marks Percentage', size=12)
plt.xlabel('Hours Studied', size=12)
plt.show()

# %%
sns.regplot(x= data['Hours'], y= data['Scores'])
plt.title('Regression Plot',size=20)
plt.ylabel('Marks Percentage', size=12)
plt.xlabel('Hours Studied', size=12)
plt.show()
print(data.corr())
# Out:
#            Hours    Scores
# Hours   1.000000  0.976191
# Scores  0.976191  1.000000

# %% [markdown]
# # SPLITTING THE DATA .

# %%
X = data.iloc[:, :-1].values         # Defining X from the Data 
y = data.iloc[:, 1].values           # Defining y from the Data

train_X, val_X, train_y, val_y = train_test_split(X, y, random_state = 0)           # Spliting the Data

# %% [markdown]
# # FITTING DATA INTO THE MODEL .

# %%
regression = LinearRegression()
regression.fit(train_X, train_y)
print("NOW THE MODEL TRAINED ")
# Out:
# NOW THE MODEL TRAINED

# %% [markdown]
# # PREDICTION OF THE PERCENTAGE OF MARKS .

# %%
pred_y = regression.predict(val_X)
prediction = pd.DataFrame({'Hours': [i[0] for i in val_X], 'Predicted Marks': [k for k in pred_y]})
prediction
# Out:
#    Hours  Predicted Marks
# 0    1.5        16.844722
# 1    3.2        33.745575
# 2    7.4        75.500624
# 3    2.5        26.786400
# 4    5.9        60.588106
# 5    3.8        39.710582
# 6    1.9        20.821393

# %% [markdown]
# # COMPARISON BETWEEN THE PREDICTED MARKS AND THE ACTUAL MARKS .

# %%
compare_scores = pd.DataFrame({'Actual Marks': val_y, 'Predicted Marks': pred_y})
compare_scores
# Out:
#    Actual Marks  Predicted Marks
# 0            20        16.844722
# 1            27        33.745575
# 2            69        75.500624
# 3            30        26.786400
# 4            62        60.588106
# 5            35        39.710582
# 6            24        20.821393

# %% [markdown]
# # PLOTTING BETWEEN ACTUAL AND PREDICTED MARKS .

# %%
plt.scatter(x=val_X, y=val_y, color='blue')
plt.plot(val_X, pred_y, color='Black')
plt.title('Actual vs Predicted', size=20)
plt.ylabel('Marks Percentage', size=12)
plt.xlabel('Hours Studied', size=12)
plt.show()

# %% [markdown]
# # ACCURACY OF THE MODEL .

# %%
print('Mean absolute error: ',mean_absolute_error(val_y,pred_y))
# Out:
# Mean absolute error:  4.130879918502482

# %% [markdown]
# THE FINAL OUTPUT OF THE PROJECT .
#
#
# #  What will be the predicted score of a student if he/she studies for 9.25 hrs/ day  ?

# %%
hours = [9.25]
answer = regression.predict([hours])
print("SCORE OF THE STUDENT IF HE/SHE STUDIES FOR 9.25 HRS/DAY = {}".format(round(answer[0],3)))
# Out:
# SCORE OF THE STUDENT IF HE/SHE STUDIES FOR 9.25 HRS/DAY = 93.893

# %% [markdown]
# # IF A SUDENT STUDIED FOR 9.25 hrs/day,  HE/SHE IS LIKELY TO SCORE 93.893 MARKS .
